# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import osmnx as ox
import networkx as nx
from shapely import to_geojson
from keplergl import KeplerGl

# %matplotlib inline

# %%
headers = pd.read_csv('../data/external/TripBulkReport/schema/TripBulkReportTripsHeaders.csv').columns

# %%
df = pd.read_csv('../data/external/TripBulkReport/data/trips.csv', header=None)
df.drop([len(headers)], axis=1, inplace=True)
df.columns = headers
df.head()
# Out:
#                              TripId                          DeviceId  \
# 0  00680db75571fdb2ed00fc87b1b419ef  8867e80fcdbb3d6b74e73339f72ef8dc
# 1  00e7ac3b46277d46b9cc31d4821cfea4  69c400ce2c69ad168e0366f65244bb41
# 2  0135963269dbb22d3bb82ddd46b25d46  c83fad98fe1936a88a7d85135e91b8f6
# 3  0289a5664287f93a28157cfe95df3042  e14ac160a67a08a25c7422f16b561ec2
# 4  045c25562a5f7fcc906b08f4175b2dad  8d4540b29323e3bfba4db57be982b5f5
#
#                          ProviderId  Mode                 StartDate  \
# 0  98b297950041a42470269d56260243a1     1  2024-08-06T13:30:57.000Z
# 1  7fe1f8abaad094e0b5cb1b01d712f708     1  2024-08-07T11:07:37.000Z
# 2  8e6b42f1644ecb1327dc03ab345e618b     1  2024-08-04T09:32:56.999Z
# 3  7fe1f8abaad094e0b5cb1b01d712f708     1  2024-08-06T10:32:49.000Z
# 4  f4f6dce2f3a0f9dada0c2b5b66452017     1  2024-08-07T09:54:51.000Z
#
#    StartWDay                   EndDate  EndWDay  StartLocLat  StartLocLon  \
# ...

# %%
KeplerGl(height=600, data={'df': df_1})
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# c:\Users\FabianLandua\Documents\DKSR_GitHub\ci_city_mission_prague_2024\usecase_mobility\.venv\Lib\site-packages\jupyter_client\session.py:721: UserWarning: Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
#   content = self.pack(content)
# KeplerGl(data={'df':                                  TripId                          DeviceId  \
# 0      00680…

# %%
Sb = (50.799644, 7.207446)
G = ox.graph_from_point(Sb,dist=10000,network_type='drive',dist_type='network',truncate_by_edge=True)

# %%
G = ox.graph_from_place('Prague, Czechia',network_type='drive')

# %%
ox.plot_graph(G,node_size=0)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)
