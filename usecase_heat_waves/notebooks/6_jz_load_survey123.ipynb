# %%
import os
import sys
sys.path.append("../src")
from load_arcgis import get_survey
import pandas as pd

# %%
ARCGIS_USER = os.getenv("ARCGIS_USER")
ARCGIS_PASSWORD = os.getenv("ARCGIS_PASSWORD")

# %%
survey = get_survey(ARCGIS_USER, ARCGIS_PASSWORD)
survey["CreationDate"] = pd.to_datetime(survey["CreationDate"])
survey.set_index("CreationDate", inplace=True)
survey
# Out:
#    objectid                              globalid  \
# 0         1  9326fe8b-6a6b-4123-85c3-9fd9318ace9c
# 1         2  267c7873-efe5-4e28-8a35-1cc76a38445f
# 2         3  4536b588-0dea-41fd-83a3-ee16815c019e
# 3         4  7fa80118-d539-4a73-853e-06ffd42dbfa8
# 4         5  9ff4191a-a680-47ee-8ec3-310f186b0c00
#
#                    CreationDate     Creator                      EditDate  \
# 0 2024-09-13 13:57:00.055000067             2024-09-13 13:57:00.055000067
# 1 2024-09-13 13:59:54.655999899  Jonas_DKSR 2024-09-13 13:59:54.655999899
# 2 2024-09-13 14:00:18.009999990  Jonas_DKSR 2024-09-13 14:00:18.009999990
# 3 2024-09-13 15:10:37.986999989  Jonas_DKSR 2024-09-13 15:10:37.986999989
# 4 2024-09-15 15:44:23.542000055             2024-09-15 15:44:23.542000055
#
#        Editor how_do_you_feel describe_the_spot_where_youre_s how_noisy_is_it  \
# 0               Somewhat Cold                       Not_windy         It's ok
# ...
