# %%
import os
import sys
sys.path.append("../src")
from load_arcgis import get_survey
import pandas as pd

# %%
ARCGIS_USER = os.getenv("ARCGIS_USER")
ARCGIS_PASSWORD = os.getenv("ARCGIS_PASSWORD")

# %%
survey = get_survey(ARCGIS_USER, ARCGIS_PASSWORD)
survey["CreationDate"] = pd.to_datetime(survey["CreationDate"])
survey.set_index("CreationDate", inplace=True)
survey
# Out:
#                                objectid                              globalid  \
# CreationDate
# 2024-09-13 13:57:00.055000067         1  9326fe8b-6a6b-4123-85c3-9fd9318ace9c
# 2024-09-13 13:59:54.655999899         2  267c7873-efe5-4e28-8a35-1cc76a38445f
# 2024-09-13 14:00:18.009999990         3  4536b588-0dea-41fd-83a3-ee16815c019e
# 2024-09-13 15:10:37.986999989         4  7fa80118-d539-4a73-853e-06ffd42dbfa8
# 2024-09-15 15:44:23.542000055         5  9ff4191a-a680-47ee-8ec3-310f186b0c00
#
#                                   Creator                      EditDate  \
# CreationDate
# 2024-09-13 13:57:00.055000067             2024-09-13 13:57:00.055000067
# 2024-09-13 13:59:54.655999899  Jonas_DKSR 2024-09-13 13:59:54.655999899
# 2024-09-13 14:00:18.009999990  Jonas_DKSR 2024-09-13 14:00:18.009999990
# 2024-09-13 15:10:37.986999989  Jonas_DKSR 2024-09-13 15:10:37.986999989
# 2024-09-15 15:44:23.542000055             2024-09-15 15:44:23.542000055
#
#                                    Editor how_do_you_feel  \
# CreationDate
# 2024-09-13 13:57:00.055000067               Somewhat Cold
# 2024-09-13 13:59:54.655999899  Jonas_DKSR   Somewhat Cold
# 2024-09-13 14:00:18.009999990  Jonas_DKSR         Neutral
# 2024-09-13 15:10:37.986999989  Jonas_DKSR         Neutral
# 2024-09-15 15:44:23.542000055                     Neutral
#
#                               describe_the_spot_where_youre_s how_noisy_is_it  \
# CreationDate
# 2024-09-13 13:57:00.055000067                       Not_windy         It's ok
# 2024-09-13 13:59:54.655999899                         Indoors         It's ok
# 2024-09-13 14:00:18.009999990                         Indoors         It's ok
# 2024-09-13 15:10:37.986999989                         Indoors         It's ok
# 2024-09-15 15:44:23.542000055                           other         It's ok
#
#                               describe_the_spot_where_y_other  \
# CreationDate
# 2024-09-13 13:57:00.055000067                            <NA>
# 2024-09-13 13:59:54.655999899                            <NA>
# 2024-09-13 14:00:18.009999990                            <NA>
# 2024-09-13 15:10:37.986999989                            <NA>
# 2024-09-15 15:44:23.542000055                      On a Train
#
#                                                                            SHAPE
# CreationDate
# 2024-09-13 13:57:00.055000067  {"x": 13.325074099999776, "y": 52.488250199999...
# 2024-09-13 13:59:54.655999899  {"x": 13.358170899999774, "y": 52.496323599999...
# 2024-09-13 14:00:18.009999990  {"x": 13.347776999999775, "y": 52.495329499999...
# 2024-09-13 15:10:37.986999989  {"x": 13.348279467264318, "y": 52.495934249913...
# 2024-09-15 15:44:23.542000055  {"x": 13.333299199999775, "y": 52.500889599999...

# %%
from arcgis.gis import GIS
import os, re, _csv
from dotenv import load_dotenv
load_dotenv()

portalURL = "https://www.arcgis.com"
ARCGIS_USER = os.getenv("ARCGIS_USER")
ARCGIS_PASSWORD = os.getenv("ARCGIS_PASSWORD")
survey_item_id = "c0da843348f24012885615cb6d611d8d"
save_path = "../data/raw/arcgis_survey"
keep_org_item = False
store_csv_w_attachments = False

gis = GIS(portalURL, ARCGIS_USER, ARCGIS_PASSWORD)
survey_by_id = gis.content.get(survey_item_id)
